# %%
import arcgis
import pandas as pd
from arcgis.gis import GIS

# %%
APSD = pd.read_csv("../Datasets/Annual_Parking_Study_Data.csv")
APSD.head()
# Out:
# E:\Anaconda\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Elmntkey          Study_Area Sub_Area         Date Time Side  \
# 0    1577.0  12th Ave - Weekday      NaN  4-08-14 14:00:00    W
# 1    1577.0  12th Ave - Weekday      NaN  4-08-14 15:00:00    W
# 2    1577.0  12th Ave - Weekday      NaN  4-08-14 13:00:00    W
# 3    1577.0  12th Ave - Weekday      NaN  4-08-14 09:00:00    W
# 4    1577.0  12th Ave - Weekday      NaN  4-08-14 12:00:00    W
#
#                                          Unitdesc Peak Hour_SDOT  \
# 0  12TH AVE BETWEEN E COLUMBIA ST AND E MARION ST            NaN
# 1  12TH AVE BETWEEN E COLUMBIA ST AND E MARION ST            NaN
# 2  12TH AVE BETWEEN E COLUMBIA ST AND E MARION ST            NaN
# 3  12TH AVE BETWEEN E COLUMBIA ST AND E MARION ST            NaN
# ...

# %%
gis = GIS()

# %%
streets = gis.content.search("title: Seattle Streets AND owner: Transportation_SeattleCityGIS", item_type = "Feature Layer", outside_org=True)
streets
# Out:
# [<Item title:"Seattle Streets" type:Feature Layer Collection owner:Transportation_SeattleCityGIS>]

# %%
Seattle = gis.map("Seattle", 10)
Seattle
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=10.0)

# %%
Seattle.add_layer(streets)

# %%
sdf = pd.DataFrame.spatial.from_layer(streets[0].layers[0])

# %%
sdf
# Out:
#        ARTCLASS         ARTDESCRIPT  BLOCKNBR  COMPKEY DIRHI DIRLO FLOW  \
# 0           2.0      Minor Arterial     800.0     1002    SE    NW
# 1           2.0      Minor Arterial    2800.0     1020    SE    NW
# 2           1.0  Principal Arterial     500.0     1029     S     N    F
# 3           0.0      Not Designated    2700.0     1057     S     N
# 4           0.0      Not Designated    5000.0     1069     S     N
# 5           0.0      Not Designated    5600.0     1074     S     N
# 6           3.0  Collector Arterial   13300.0     1108     S     N
# 7           0.0      Not Designated    3900.0     1117     S     N
# 8           0.0      Not Designated    5900.0     1138     S     N
# 9           0.0      Not Designated    6500.0     1141     S     N
# 10          0.0      Not Designated    7900.0     1151     S     N
# 11          0.0      Not Designated   11600.0     1171     S     N
# 12          0.0      Not Designated   13700.0     1181     S     N
# ...

# %%
Seattle1 = gis.map("Seattle", 10)
Seattle1
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=10.0)

# %%
sdf.spatial.plot(map_widget = Seattle1, symbol_type='simple', color = 'autumn')
# Out:
# True

# %%
for idx, row in sdf.iterrows():
    Seattle1.draw(row['SHAPE'])
# Out:
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ...
