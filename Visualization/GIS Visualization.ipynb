# %%
from data_retrieve import get_data

# %%
url = "https://opendata.arcgis.com/datasets/411a96b39c834a2380a256b8afa5003b_0.csv"
filename = "../Datasets/Street_Signs/Street_Signs"

# %%
df = get_data(url, filename)
# Out:
# The file ../Datasets/Street_Signs/Street_Signs already exists.
# /Users/Zack/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2802: DtypeWarning: Columns (23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):

# %%
df.head()
# Out:
#             X          Y  OBJECTID  COMPKEY  COMPTYPE  SEGKEY  INTKEY  \
# 0 -122.337074  47.618465      2001   702942        20   13117       1
# 1 -122.343469  47.612861      2002   698033        20    2762       1
# 2 -122.276785  47.548376      2003   699058        20   12397       1
# 3 -122.323899  47.680746      2004   698475        20   17447       1
# 4 -122.392835  47.660792      2005   698403        20   10644       1
#
#    ELMNTKEY      UNITID UNITTYPE   ...     \
# 0     81114  SGN-217383    01-RS   ...
# 1     70750  SGN-215318    01-RS   ...
# 2     80390  SGN-215813    01-RS   ...
# 3     85385  SGN-215593    01-RS   ...
# 4     33402  SGN-215564    01-RS   ...
#
#                                                 TEXT  \
# 0                                               STOP
# 1  30 MINUTE COMMERCIAL OR PERMIT VEHICLE\n\rLOAD...
# 2                                     SPEED LIMIT 25
# 3  [CIRCLE P] 2 Hours Max\n\r3 Hours Max After 5p...
# ...

# %%
# select the column "COMPKEY" "SHAPE_LNG" "SHAPE_LAT"
